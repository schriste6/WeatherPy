# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_desc = city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | ilulissat
# Processing Record 6 of Set 1 | porterville
# Processing Record 7 of Set 1 | constitucion
# Processing Record 8 of Set 1 | itarema
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | ahuimanu
# Processing Record 11 of Set 1 | lagoa
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | bac lieu
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | acapulco
# Processing Record 20 of Set 1 | coruripe
# Processing Record 21 of Set 1 | sao miguel
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | vrangel
# Processing Record 26 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 27 of Set 1 | saldanha
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | margherita
# Processing Record 30 of Set 1 | ixtapa
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | kijang
# Processing Record 35 of Set 1 | sola
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | portland
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | miranda
# Processing Record 44 of Set 1 | half moon bay
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 1 | whitehorse
# Processing Record 48 of Set 1 | indiana
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | mango
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | santa isabel do rio negro
# Processing Record 6 of Set 2 | tsumeb
# Processing Record 7 of Set 2 | kiruna
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | rikitea
# Processing Record 10 of Set 2 | vao
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | baheri
# Processing Record 13 of Set 2 | nesna
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | avera
# Processing Record 16 of Set 2 | apache junction
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 2 | ostrovnoy
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | nouakchott
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | viedma
# Processing Record 26 of Set 2 | george
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | lagos
# Processing Record 29 of Set 2 | korhogo
# Processing Record 30 of Set 2 | takoradi
# Processing Record 31 of Set 2 | chambersburg
# Processing Record 32 of Set 2 | touros
# Processing Record 33 of Set 2 | armacao dos buzios
# City not found. Skipping...
# Processing Record 34 of Set 2 | tubuala
# Processing Record 35 of Set 2 | evensk
# Processing Record 36 of Set 2 | namatanai
# Processing Record 37 of Set 2 | klaksvik
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | renqiu
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | chadan
# Processing Record 44 of Set 2 | itanhaem
# Processing Record 45 of Set 2 | te anau
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | mangan
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | fukue
# Processing Record 1 of Set 3 | shelburne
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | manjhanpur
# Processing Record 4 of Set 3 | karratha
# Processing Record 5 of Set 3 | udachnyy
# Processing Record 6 of Set 3 | tumaco
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | cayenne
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | fairbanks
# Processing Record 12 of Set 3 | santa vitoria do palmar
# Processing Record 13 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | tupik
# Processing Record 16 of Set 3 | gizo
# Processing Record 17 of Set 3 | nokaneng
# Processing Record 18 of Set 3 | vostok
# Processing Record 19 of Set 3 | maldonado
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | zapolyarnyy
# Processing Record 23 of Set 3 | san pedro de ycuamandiyu
# Processing Record 24 of Set 3 | concepcion del uruguay
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | camana
# Processing Record 27 of Set 3 | virtsu
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | yurginskoye
# Processing Record 30 of Set 3 | taoudenni
# Processing Record 31 of Set 3 | olafsvik
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | beira
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | springbok
# Processing Record 36 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 3 | posse
# Processing Record 38 of Set 3 | male
# Processing Record 39 of Set 3 | abnub
# Processing Record 40 of Set 3 | goderich
# Processing Record 41 of Set 3 | yellowknife
# Processing Record 42 of Set 3 | broome
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | kruisfontein
# Processing Record 45 of Set 3 | rio gallegos
# Processing Record 46 of Set 3 | palmaner
# Processing Record 47 of Set 3 | san cristobal
# Processing Record 48 of Set 3 | seoul
# Processing Record 49 of Set 3 | kattivakkam
# Processing Record 50 of Set 3 | conde
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | valdivia
# Processing Record 3 of Set 4 | norden
# Processing Record 4 of Set 4 | flinders
# Processing Record 5 of Set 4 | donghai
# Processing Record 6 of Set 4 | cabra
# Processing Record 7 of Set 4 | tahta
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | bardiyah
# Processing Record 10 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 4 | nam tha
# City not found. Skipping...
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | mananara
# Processing Record 14 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | taltal
# Processing Record 17 of Set 4 | pochutla
# Processing Record 18 of Set 4 | dwarka
# Processing Record 19 of Set 4 | buraydah
# Processing Record 20 of Set 4 | trenggalek
# Processing Record 21 of Set 4 | okhotsk
# Processing Record 22 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 4 | sur
# Processing Record 24 of Set 4 | pitimbu
# Processing Record 25 of Set 4 | fuerte olimpo
# Processing Record 26 of Set 4 | itapecerica
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | hilo
# Processing Record 29 of Set 4 | rundu
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | grindavik
# Processing Record 32 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 4 | bambous virieux
# Processing Record 34 of Set 4 | akdepe
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | saint-paul
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | port-cartier
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | dunedin
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | visnes
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | progreso
# Processing Record 46 of Set 4 | mzimba
# Processing Record 47 of Set 4 | olga
# Processing Record 48 of Set 4 | roebourne
# Processing Record 49 of Set 4 | fjerritslev
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | muros
# Processing Record 3 of Set 5 | college
# Processing Record 4 of Set 5 | ouro preto do oeste
# Processing Record 5 of Set 5 | rosarito
# Processing Record 6 of Set 5 | guadalupe
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | key west
# Processing Record 9 of Set 5 | treinta y tres
# Processing Record 10 of Set 5 | sayyan
# Processing Record 11 of Set 5 | wajima
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | baruun-urt
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | berdigestyakh
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | dingle
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | halifax
# Processing Record 21 of Set 5 | quang ngai
# Processing Record 22 of Set 5 | pinega
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | samarai
# Processing Record 25 of Set 5 | carlsbad
# Processing Record 26 of Set 5 | katghora
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | deputatskiy
# Processing Record 29 of Set 5 | caraquet
# Processing Record 30 of Set 5 | yulara
# Processing Record 31 of Set 5 | maniitsoq
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | morong
# Processing Record 34 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 5 | belyy yar
# Processing Record 36 of Set 5 | lhuntshi
# City not found. Skipping...
# Processing Record 37 of Set 5 | zhuhai
# Processing Record 38 of Set 5 | satun
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | coleraine
# Processing Record 41 of Set 5 | aykhal
# Processing Record 42 of Set 5 | togur
# Processing Record 43 of Set 5 | laguna
# Processing Record 44 of Set 5 | mogocha
# Processing Record 45 of Set 5 | mount pleasant
# Processing Record 46 of Set 5 | mahebourg
# Processing Record 47 of Set 5 | sakakah
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | epe
# Processing Record 50 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | krasnoselkup
# Processing Record 5 of Set 6 | sumbe
# Processing Record 6 of Set 6 | hay river
# Processing Record 7 of Set 6 | batagay
# Processing Record 8 of Set 6 | vanino
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | tibiri
# Processing Record 11 of Set 6 | shahr-e kord
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | beloha
# Processing Record 14 of Set 6 | sept-iles
# Processing Record 15 of Set 6 | tuktoyaktuk
# Processing Record 16 of Set 6 | druskininkai
# Processing Record 17 of Set 6 | saint-michel-des-saints
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | tuatapere
# Processing Record 20 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 21 of Set 6 | gonbad-e qabus
# Processing Record 22 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 6 | the valley
# Processing Record 25 of Set 6 | kahului
# Processing Record 26 of Set 6 | joshimath
# Processing Record 27 of Set 6 | mazatlan
# Processing Record 28 of Set 6 | pemangkat
# Processing Record 29 of Set 6 | thompson
# Processing Record 30 of Set 6 | willmar
# Processing Record 31 of Set 6 | hellvik
# Processing Record 32 of Set 6 | la primavera
# Processing Record 33 of Set 6 | mongar
# Processing Record 34 of Set 6 | vardo
# Processing Record 35 of Set 6 | palma soriano
# Processing Record 36 of Set 6 | codrington
# Processing Record 37 of Set 6 | klyuchi
# Processing Record 38 of Set 6 | great falls
# Processing Record 39 of Set 6 | saint anthony
# Processing Record 40 of Set 6 | ryotsu
# Processing Record 41 of Set 6 | margate
# Processing Record 42 of Set 6 | anloga
# Processing Record 43 of Set 6 | sovetskiy
# Processing Record 44 of Set 6 | onega
# Processing Record 45 of Set 6 | noumea
# Processing Record 46 of Set 6 | saint-augustin
# Processing Record 47 of Set 6 | bogorodskoye
# Processing Record 48 of Set 6 | kodinsk
# Processing Record 49 of Set 6 | tagbac
# Processing Record 50 of Set 6 | kananga
# Processing Record 1 of Set 7 | olinda
# Processing Record 2 of Set 7 | castro
# Processing Record 3 of Set 7 | tezu
# Processing Record 4 of Set 7 | miquelon
# Processing Record 5 of Set 7 | tautira
# Processing Record 6 of Set 7 | havelock
# Processing Record 7 of Set 7 | burnie
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | matara
# Processing Record 11 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 7 | dalnerechensk
# Processing Record 13 of Set 7 | zyryanka
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | bafoulabe
# Processing Record 16 of Set 7 | tevaitoa
# Processing Record 17 of Set 7 | isangel
# Processing Record 18 of Set 7 | ferme-neuve
# Processing Record 19 of Set 7 | naze
# Processing Record 20 of Set 7 | soure
# Processing Record 21 of Set 7 | daru
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | nahrin
# Processing Record 24 of Set 7 | edgewater
# Processing Record 25 of Set 7 | kalengwa
# Processing Record 26 of Set 7 | airai
# Processing Record 27 of Set 7 | ponta pora
# Processing Record 28 of Set 7 | ulcinj
# Processing Record 29 of Set 7 | ambilobe
# Processing Record 30 of Set 7 | store heddinge
# Processing Record 31 of Set 7 | omsukchan
# Processing Record 32 of Set 7 | okha
# Processing Record 33 of Set 7 | san carlos de bariloche
# Processing Record 34 of Set 7 | nenjiang
# Processing Record 35 of Set 7 | luanda
# Processing Record 36 of Set 7 | neiafu
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | papara
# Processing Record 39 of Set 7 | haines junction
# Processing Record 40 of Set 7 | dobryatino
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | bereda
# Processing Record 43 of Set 7 | sao joao da barra
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | mercedes
# Processing Record 46 of Set 7 | boyabat
# Processing Record 47 of Set 7 | ponta delgada
# Processing Record 48 of Set 7 | port hedland
# Processing Record 49 of Set 7 | elizabeth city
# Processing Record 50 of Set 7 | cidreira
# Processing Record 1 of Set 8 | fasa
# Processing Record 2 of Set 8 | labuhan
# Processing Record 3 of Set 8 | para de minas
# Processing Record 4 of Set 8 | marsh harbour
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | tiarei
# Processing Record 7 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 8 | bilma
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | oktyabrskoye
# Processing Record 11 of Set 8 | dauphin
# Processing Record 12 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 13 of Set 8 | kununurra
# Processing Record 14 of Set 8 | stornoway
# Processing Record 15 of Set 8 | mutoko
# Processing Record 16 of Set 8 | veraval
# Processing Record 17 of Set 8 | bilibino
# Processing Record 18 of Set 8 | chokurdakh
# Processing Record 19 of Set 8 | katsuura
# Processing Record 20 of Set 8 | lira
# Processing Record 21 of Set 8 | molnlycke
# Processing Record 22 of Set 8 | fort smith
# Processing Record 23 of Set 8 | tessalit
# Processing Record 24 of Set 8 | tres lagoas
# Processing Record 25 of Set 8 | riyadh
# Processing Record 26 of Set 8 | auki
# Processing Record 27 of Set 8 | mount darwin
# Processing Record 28 of Set 8 | ngunguru
# Processing Record 29 of Set 8 | bulolo
# Processing Record 30 of Set 8 | emerald
# Processing Record 31 of Set 8 | kasongo
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | tilichiki
# Processing Record 34 of Set 8 | stolbovaya
# Processing Record 35 of Set 8 | harper
# Processing Record 36 of Set 8 | pangai
# Processing Record 37 of Set 8 | cumana
# Processing Record 38 of Set 8 | keuruu
# Processing Record 39 of Set 8 | toamasina
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | surubim
# Processing Record 42 of Set 8 | dubai
# Processing Record 43 of Set 8 | tateyama
# Processing Record 44 of Set 8 | muravlenko
# Processing Record 45 of Set 8 | brotas
# Processing Record 46 of Set 8 | osorno
# Processing Record 47 of Set 8 | sorong
# Processing Record 48 of Set 8 | mabaruma
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 9 | abu dhabi
# Processing Record 2 of Set 9 | rawson
# Processing Record 3 of Set 9 | nioro
# Processing Record 4 of Set 9 | padilla
# Processing Record 5 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 9 | uniontown
# Processing Record 7 of Set 9 | aklavik
# Processing Record 8 of Set 9 | sitka
# Processing Record 9 of Set 9 | dunda
# Processing Record 10 of Set 9 | vestmannaeyjar
# Processing Record 11 of Set 9 | longyearbyen
# Processing Record 12 of Set 9 | pangody
# Processing Record 13 of Set 9 | pacific grove
# Processing Record 14 of Set 9 | mingguang
# Processing Record 15 of Set 9 | pangkalanbuun
# Processing Record 16 of Set 9 | levokumskoye
# Processing Record 17 of Set 9 | west wendover
# Processing Record 18 of Set 9 | jinka
# Processing Record 19 of Set 9 | goksun
# Processing Record 20 of Set 9 | bonfim
# Processing Record 21 of Set 9 | teya
# Processing Record 22 of Set 9 | port-gentil
# Processing Record 23 of Set 9 | kabanjahe
# Processing Record 24 of Set 9 | mbini
# Processing Record 25 of Set 9 | kollam
# Processing Record 26 of Set 9 | kem
# Processing Record 27 of Set 9 | bulawayo
# Processing Record 28 of Set 9 | sandwick
# Processing Record 29 of Set 9 | mahon
# Processing Record 30 of Set 9 | ahipara
# Processing Record 31 of Set 9 | koslan
# Processing Record 32 of Set 9 | xianyang
# Processing Record 33 of Set 9 | korla
# Processing Record 34 of Set 9 | coihaique
# Processing Record 35 of Set 9 | riacho de santana
# Processing Record 36 of Set 9 | banjar
# Processing Record 37 of Set 9 | havre-saint-pierre
# Processing Record 38 of Set 9 | yurino
# Processing Record 39 of Set 9 | maimon
# City not found. Skipping...
# Processing Record 40 of Set 9 | puerto escondido
# Processing Record 41 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 9 | teruel
# Processing Record 43 of Set 9 | guasdualito
# Processing Record 44 of Set 9 | san luis de la paz
# Processing Record 45 of Set 9 | asau
# Processing Record 46 of Set 9 | meulaboh
# Processing Record 47 of Set 9 | talaya
# Processing Record 48 of Set 9 | chiredzi
# Processing Record 49 of Set 9 | horizontina
# Processing Record 50 of Set 9 | wiwili
# Processing Record 1 of Set 10 | odesskoye
# Processing Record 2 of Set 10 | pangnirtung
# Processing Record 3 of Set 10 | arandis
# Processing Record 4 of Set 10 | aquiraz
# Processing Record 5 of Set 10 | paita
# Processing Record 6 of Set 10 | dongsheng
# Processing Record 7 of Set 10 | hami
# Processing Record 8 of Set 10 | urumqi
# Processing Record 9 of Set 10 | los llanos de aridane
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | abha
# Processing Record 12 of Set 10 | lompoc
# Processing Record 13 of Set 10 | north bend
# Processing Record 14 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 10 | wanning
# Processing Record 16 of Set 10 | arica
# Processing Record 17 of Set 10 | abbeville
# Processing Record 18 of Set 10 | tenenkou
# Processing Record 19 of Set 10 | yerbogachen
# Processing Record 20 of Set 10 | solenzo
# Processing Record 21 of Set 10 | muncar
# Processing Record 22 of Set 10 | alexandria
# Processing Record 23 of Set 10 | vung tau
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | uvat
# Processing Record 26 of Set 10 | bekeshevskaya
# Processing Record 27 of Set 10 | vila franca do campo
# Processing Record 28 of Set 10 | buin
# Processing Record 29 of Set 10 | sosnogorsk
# Processing Record 30 of Set 10 | parras
# City not found. Skipping...
# Processing Record 31 of Set 10 | clyde river
# Processing Record 32 of Set 10 | kieta
# Processing Record 33 of Set 10 | sorland
# Processing Record 34 of Set 10 | port blair
# Processing Record 35 of Set 10 | benjamin aceval
# Processing Record 36 of Set 10 | najran
# Processing Record 37 of Set 10 | banjarmasin
# Processing Record 38 of Set 10 | ballina
# Processing Record 39 of Set 10 | waycross
# Processing Record 40 of Set 10 | inirida
# Processing Record 41 of Set 10 | atambua
# Processing Record 42 of Set 10 | sobolevo
# Processing Record 43 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 10 | perieti
# Processing Record 45 of Set 10 | berlevag
# Processing Record 46 of Set 10 | hammerfest
# Processing Record 47 of Set 10 | kamiiso
# Processing Record 48 of Set 10 | zaragoza
# Processing Record 49 of Set 10 | lucapa
# Processing Record 50 of Set 10 | la ronge
# Processing Record 1 of Set 11 | mweka
# Processing Record 2 of Set 11 | yarega
# Processing Record 3 of Set 11 | lavrentiya
# Processing Record 4 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 11 | ancud
# Processing Record 6 of Set 11 | egvekinot
# Processing Record 7 of Set 11 | hasaki
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | alto paraguai
# Processing Record 10 of Set 11 | high prairie
# Processing Record 11 of Set 11 | dodge city
# Processing Record 12 of Set 11 | mattru
# Processing Record 13 of Set 11 | the pas
# Processing Record 14 of Set 11 | tual
# Processing Record 15 of Set 11 | hellin
# Processing Record 16 of Set 11 | vanavara
# Processing Record 17 of Set 11 | shetpe
# Processing Record 18 of Set 11 | palmer
# Processing Record 19 of Set 11 | solnechnyy
# Processing Record 20 of Set 11 | san fernando
# Processing Record 21 of Set 11 | puerto princesa
# Processing Record 22 of Set 11 | itoman
# Processing Record 23 of Set 11 | qiongshan
# Processing Record 24 of Set 11 | mandalgovi
# Processing Record 25 of Set 11 | ekhabi
# Processing Record 26 of Set 11 | sawtell
# Processing Record 27 of Set 11 | qaqortoq
# Processing Record 28 of Set 11 | kolosovka
# Processing Record 29 of Set 11 | challans
# Processing Record 30 of Set 11 | taree
# Processing Record 31 of Set 11 | akwatia
# Processing Record 32 of Set 11 | gat
# Processing Record 33 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 11 | waraseoni
# Processing Record 35 of Set 11 | kendal
# Processing Record 36 of Set 11 | san rafael
# Processing Record 37 of Set 11 | muroto
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | kaeo
# Processing Record 40 of Set 11 | aktau
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | itaberai
# Processing Record 43 of Set 11 | nova olinda do norte
# Processing Record 44 of Set 11 | bombay
# Processing Record 45 of Set 11 | vanimo
# Processing Record 46 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 11 | morehead
# Processing Record 48 of Set 11 | sulangan
# Processing Record 49 of Set 11 | donskoye
# Processing Record 50 of Set 11 | coquimbo
# Processing Record 1 of Set 12 | morondava
# Processing Record 2 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 3 of Set 12 | kiunga
# Processing Record 4 of Set 12 | rabo de peixe
# Processing Record 5 of Set 12 | paraje nuevo
# Processing Record 6 of Set 12 | altamira
# Processing Record 7 of Set 12 | ures
# Processing Record 8 of Set 12 | wanaka
# Processing Record 9 of Set 12 | tuy hoa
# Processing Record 10 of Set 12 | gulariya
# Processing Record 11 of Set 12 | pevek
# Processing Record 12 of Set 12 | antalaha
# Processing Record 13 of Set 12 | petatlan
# Processing Record 14 of Set 12 | avenal
# Processing Record 15 of Set 12 | qui nhon
# Processing Record 16 of Set 12 | neuquen
# Processing Record 17 of Set 12 | wageningen
# Processing Record 18 of Set 12 | belaya gora
# Processing Record 19 of Set 12 | takaka
# Processing Record 20 of Set 12 | lahij
# Processing Record 21 of Set 12 | bar harbor
# Processing Record 22 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 12 | reading
# Processing Record 24 of Set 12 | derzhavinsk
# Processing Record 25 of Set 12 | mehamn
# Processing Record 26 of Set 12 | tatui
# Processing Record 27 of Set 12 | pokhara
# Processing Record 28 of Set 12 | dickinson
# Processing Record 29 of Set 12 | camacha
# Processing Record 30 of Set 12 | pasighat
# Processing Record 31 of Set 12 | juneau
# Processing Record 32 of Set 12 | yumen
# Processing Record 33 of Set 12 | bonavista
# Processing Record 34 of Set 12 | mapiri
# Processing Record 35 of Set 12 | aksum
# Processing Record 36 of Set 12 | asekeyevo
# Processing Record 37 of Set 12 | husavik
# Processing Record 38 of Set 12 | chiang rai
# Processing Record 39 of Set 12 | mbandaka
# Processing Record 40 of Set 12 | mafeteng
# Processing Record 41 of Set 12 | xiongyue
# Processing Record 42 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 12 | namie
# Processing Record 44 of Set 12 | bereznik
# Processing Record 45 of Set 12 | padang
# Processing Record 46 of Set 12 | wamba
# Processing Record 47 of Set 12 | mbanza-ngungu
# Processing Record 48 of Set 12 | cartagena
# Processing Record 49 of Set 12 | batouri
# Processing Record 50 of Set 12 | lyubokhna
# Processing Record 1 of Set 13 | ginir
# Processing Record 2 of Set 13 | thunder bay
# Processing Record 3 of Set 13 | sosua
# Processing Record 4 of Set 13 | westport
# Processing Record 5 of Set 13 | kuantan
# Processing Record 6 of Set 13 | vicksburg
# Processing Record 7 of Set 13 | mayo
# Processing Record 8 of Set 13 | belmonte
# Processing Record 9 of Set 13 | dudhani
# Processing Record 10 of Set 13 | yemtsa
# Processing Record 11 of Set 13 | krivosheino
# Processing Record 12 of Set 13 | huarmey
# Processing Record 13 of Set 13 | huanan
# Processing Record 14 of Set 13 | ahero
# Processing Record 15 of Set 13 | kiama
# Processing Record 16 of Set 13 | sao raimundo das mangabeiras
# Processing Record 17 of Set 13 | bastrop
# Processing Record 18 of Set 13 | moerai
# Processing Record 19 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 13 | sansai
# City not found. Skipping...
# Processing Record 21 of Set 13 | uong bi
# Processing Record 22 of Set 13 | gavle
# Processing Record 23 of Set 13 | nuuk
# Processing Record 24 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | malakal
# Processing Record 26 of Set 13 | aksarka
# Processing Record 27 of Set 13 | sungairaya
# Processing Record 28 of Set 13 | kizilskoye
# Processing Record 29 of Set 13 | santarem
# Processing Record 30 of Set 13 | bosaso
# Processing Record 31 of Set 13 | bonthe
# Processing Record 32 of Set 13 | port moresby
# Processing Record 33 of Set 13 | sug-aksy
# City not found. Skipping...
# Processing Record 34 of Set 13 | necochea
# Processing Record 35 of Set 13 | brazzaville
# Processing Record 36 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 37 of Set 13 | sioux lookout
# Processing Record 38 of Set 13 | dubbo
# Processing Record 39 of Set 13 | chebenki
# Processing Record 40 of Set 13 | gambo
# Processing Record 41 of Set 13 | punta de piedra
# Processing Record 42 of Set 13 | samdari
# Processing Record 43 of Set 13 | jobat
# Processing Record 44 of Set 13 | mwinilunga
# Processing Record 45 of Set 13 | faya
# Processing Record 46 of Set 13 | saint-joseph
# Processing Record 47 of Set 13 | hokitika
# Processing Record 48 of Set 13 | man
# Processing Record 49 of Set 13 | lakatoro
# Processing Record 50 of Set 13 | ust-kulom
# Processing Record 1 of Set 14 | oudtshoorn
# Processing Record 2 of Set 14 | benguela
# Processing Record 3 of Set 14 | malaya purga
# Processing Record 4 of Set 14 | dhidhdhoo
# Processing Record 5 of Set 14 | katobu
# Processing Record 6 of Set 14 | moose factory
# Processing Record 7 of Set 14 | basoko
# Processing Record 8 of Set 14 | kuytun
# Processing Record 9 of Set 14 | andenes
# Processing Record 10 of Set 14 | dharchula
# Processing Record 11 of Set 14 | meridian
# Processing Record 12 of Set 14 | gariaband
# Processing Record 13 of Set 14 | krasnyy chikoy
# Processing Record 14 of Set 14 | lorengau
# Processing Record 15 of Set 14 | sabang
# Processing Record 16 of Set 14 | duncan
# Processing Record 17 of Set 14 | sibu
# Processing Record 18 of Set 14 | pravia
# Processing Record 19 of Set 14 | bryan
# Processing Record 20 of Set 14 | skhisma
# Processing Record 21 of Set 14 | san joaquin
# Processing Record 22 of Set 14 | nantucket
# Processing Record 23 of Set 14 | spring valley
# Processing Record 24 of Set 14 | bandrele
# Processing Record 25 of Set 14 | kurtamysh
# Processing Record 26 of Set 14 | uwajima
# Processing Record 27 of Set 14 | hambantota
# Processing Record 28 of Set 14 | hoquiam
# Processing Record 29 of Set 14 | oranjemund
# Processing Record 30 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 14 | merauke
# Processing Record 32 of Set 14 | micheweni
# Processing Record 33 of Set 14 | makung
# City not found. Skipping...
# Processing Record 34 of Set 14 | hakkari
# Processing Record 35 of Set 14 | kyren
# Processing Record 36 of Set 14 | mangai
# Processing Record 37 of Set 14 | slave lake
# Processing Record 38 of Set 14 | ringebu
# Processing Record 39 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 14 | henties bay
# Processing Record 41 of Set 14 | marzuq
# Processing Record 42 of Set 14 | qasigiannguit
# Processing Record 43 of Set 14 | ankazobe
# Processing Record 44 of Set 14 | prince rupert
# Processing Record 45 of Set 14 | midyat
# Processing Record 46 of Set 14 | khanpur
# Processing Record 47 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 14 | madaripur
# Processing Record 49 of Set 14 | taganak
# Processing Record 50 of Set 14 | homer
# Processing Record 1 of Set 15 | flin flon
# Processing Record 2 of Set 15 | sarangani
# Processing Record 3 of Set 15 | coshocton
# Processing Record 4 of Set 15 | atasu
# Processing Record 5 of Set 15 | prachuap khiri khan
# Processing Record 6 of Set 15 | canete
# Processing Record 7 of Set 15 | ankang
# Processing Record 8 of Set 15 | bemban
# Processing Record 9 of Set 15 | suriapet
# Processing Record 10 of Set 15 | gravdal
# Processing Record 11 of Set 15 | saint-francois
# Processing Record 12 of Set 15 | moscow
# Processing Record 13 of Set 15 | naryan-mar
# Processing Record 14 of Set 15 | nadadores
# Processing Record 15 of Set 15 | soyo
# Processing Record 16 of Set 15 | altstatten
# Processing Record 17 of Set 15 | nishihara
# Processing Record 18 of Set 15 | magadan
# Processing Record 19 of Set 15 | krasnaya yaruga
# Processing Record 20 of Set 15 | scottsbluff
# Processing Record 21 of Set 15 | quesnel
# Processing Record 22 of Set 15 | tarakeswar
# Processing Record 23 of Set 15 | sao jose da coroa grande
# Processing Record 24 of Set 15 | poltavka
# Processing Record 25 of Set 15 | tobermory
# Processing Record 26 of Set 15 | panguipulli
# Processing Record 27 of Set 15 | nuzvid
# Processing Record 28 of Set 15 | tahe
# Processing Record 29 of Set 15 | golubitskaya
# Processing Record 30 of Set 15 | verkhnyaya inta
# Processing Record 31 of Set 15 | port macquarie
# Processing Record 32 of Set 15 | awjilah
# Processing Record 33 of Set 15 | marawi
# Processing Record 34 of Set 15 | plettenberg bay
# Processing Record 35 of Set 15 | saveh
# Processing Record 36 of Set 15 | warrington
# Processing Record 37 of Set 15 | shumikha
# Processing Record 38 of Set 15 | vilcun
# Processing Record 39 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 15 | kaniama
# Processing Record 41 of Set 15 | sarakhs
# Processing Record 42 of Set 15 | lolua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     73.04        42          95
# 1         Bluff -46.6000  168.3333     53.80        62         100
# 2        Narsaq  60.9167  -46.0500     21.42        96         100
# 3     Upernavik  72.7868  -56.1549     -3.87        66         100
# 4     Ilulissat  69.2167  -51.1000     15.13        66         100
# 5   Porterville  36.0652 -119.0168     33.75        86           0
# 6  Constitucion -35.3333  -72.4167     67.53        64           9
# 7       Itarema  -2.9248  -39.9167     86.59        61         100
# 8        Avarua -21.2078 -159.7750     78.85        83          20
# 9      Ahuimanu  21.4447 -157.8378     73.11        79           0
#
#    Wind Speed Current Description Country
# 0        8.55     overcast clouds      AU
# 1        5.88     overcast clouds      NZ
# 2        2.73                snow      GL
# 3        4.72     overcast clouds      GL
# 4       12.06     overcast clouds      GL
# 5        5.75           clear sky      US
# 6        6.64           clear sky      CL
# 7       15.97     overcast clouds      BR
# 8       10.36          few clouds      CK
# 9        1.01           clear sky      US

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     73.04        42          95
# 1         Bluff      NZ -46.6000  168.3333     53.80        62         100
# 2        Narsaq      GL  60.9167  -46.0500     21.42        96         100
# 3     Upernavik      GL  72.7868  -56.1549     -3.87        66         100
# 4     Ilulissat      GL  69.2167  -51.1000     15.13        66         100
# 5   Porterville      US  36.0652 -119.0168     33.75        86           0
# 6  Constitucion      CL -35.3333  -72.4167     67.53        64           9
# 7       Itarema      BR  -2.9248  -39.9167     86.59        61         100
# 8        Avarua      CK -21.2078 -159.7750     78.85        83          20
# 9      Ahuimanu      US  21.4447 -157.8378     73.11        79           0
#
#    Wind Speed Current Description
# 0        8.55     overcast clouds
# 1        5.88     overcast clouds
# 2        2.73                snow
# 3        4.72     overcast clouds
# 4       12.06     overcast clouds
# 5        5.75           clear sky
# 6        6.64           clear sky
# 7       15.97     overcast clouds
# 8       10.36          few clouds
# 9        1.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
